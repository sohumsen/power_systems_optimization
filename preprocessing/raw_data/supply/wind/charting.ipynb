# %%
import pandas as pd
import numpy as np
# import matplotlib as plt

# %%
df=pd.read_csv("output.csv")
# ax = df.iloc[:,4].plot.hist()
ax = df.iloc[:,3].plot(kind='hist',title='My title')

fig = ax.get_figure()
fig.savefig("output")
for i in range(len(df.columns)-1):
    pass
